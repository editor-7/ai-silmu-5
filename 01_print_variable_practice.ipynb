# %% [markdown]
# # 01. print와 변수 복습
#
# 이 노트북은 Week01 Day5 easy project의 첫 번째 연습입니다. 값을 변수에 담고, 그 값을 화면에 출력하는 흐름만 확인합니다.

# %% [markdown]
# ## 1. 오늘 확인할 것
#
# - 변수에 값을 넣기
# - `print()`로 값 확인하기
# - f-string으로 문장 만들기

# %%
# TODO 1: 아래 세 값을 본인에게 맞게 아주 조금만 바꿔보세요.
student_name = "박병훈"
favorite_subject = "파이썬 기초"
today_feeling = "조금 낯설지만 따라갈 수 있음"

# %% [markdown]
# ## 2. 변수 출력하기
#
# 변수를 만들었으면 바로 출력해서 내가 생각한 값이 맞는지 확인합니다.

# %%
print("이름:", )
print("연습 주제:", )
print("상태:", )
# Out:
# 이름:
# 연습 주제:
# 상태:

# %% [markdown]
# ## 3. 문장 만들기
#
# 변수 여러 개를 합쳐 한 문장으로 만들어 봅니다.

# %%
# TODO 2: 출력 문장에 들어갈 단어를 하나 바꿔보세요.
# 출력할 문장: 홍길동님은 오늘 파이썬 기초를 연습합니다.
message = f"{student_name}님은 오늘 {favorite_subject}을 연습합니다."
print(message)
print("오늘 상태:", today_feeling)
# Out:
# 박병훈님은 오늘 파이썬 기초을 연습합니다.
# 오늘 상태: 조금 낯설지만 따라갈 수 있음

# %% [markdown]
# ## 4. 직접 출력 하나 더 만들기
#
# 부담 없이 한 줄만 더 출력해 봅니다.

# %%
# TODO 3: print 문장을 하나 더 만들어보세요.
print()

# %% [markdown]
# ## 5. 완료 확인
#
# 아래 출력이 보이면 이 노트북은 끝까지 실행된 것입니다.

# %%
completion_log = {
    "notebook": "01_print_variable",
    "status": "PROJECT_EASY_DONE",
    "changed_cell_count": 3,
}
print(completion_log)
# Out:
# {'notebook': '01_print_variable', 'status': 'PROJECT_EASY_DONE', 'changed_cell_count': 3}
